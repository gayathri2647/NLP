# %%
# Import libraries
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
# Download required NLTK packages (run only once)
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Yugesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Yugesh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\Yugesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Yugesh\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
# Input text
text = "Apple Inc. was founded by Steve Jobs and Steve Wozniak in California. Narendra Modi is the Prime Minister of India."

# %%
# Tokenize the text
tokens = word_tokenize(text)

# %%
# POS Tagging
pos_tags = pos_tag(tokens)

# %%
# Named Entity Recognition (NER)
named_entities = ne_chunk(pos_tags)
print(type(named_entities))
print(named_entities)
# Out:
# <class 'nltk.tree.tree.Tree'>
# (S
#   (PERSON Apple/NNP)
#   (ORGANIZATION Inc./NNP)
#   was/VBD
#   founded/VBN
#   by/IN
#   (PERSON Steve/NNP Jobs/NNP)
#   and/CC
#   (PERSON Steve/NNP Wozniak/NNP)
#   in/IN
#   (GPE California/NNP)
#   ./.
#   (PERSON Narendra/NNP Modi/NNP)
#   is/VBZ
#   the/DT
#   Prime/NNP
#   Minister/NNP
#   of/IN
#   (GPE India/NNP)
#   ./.)

# %%
named_entities.pretty_print()
# Out:
#                                                                                   S
#     ______________________________________________________________________________|_____________________________________________________________________________________________________________________________________
#    |         |        |     |      |    |    |      |        |          |         |    |    PERSON  ORGANIZATION           PERSON                    PERSON                  GPE                    PERSON             GPE
#    |         |        |     |      |    |    |      |        |          |         |    |      |          |            _______|_______           _______|_________             |              _________|_______          |
# was/VBD founded/VBN by/IN and/CC in/IN ./. is/VBZ the/DT Prime/NNP Minister/NNP of/IN ./. Apple/NNP   Inc./NNP   Steve/NNP        Jobs/NNP Steve/NNP        Wozniak/NNP California/NNP Narendra/NNP        Modi/NNP India/NNP
