# %%
# Import libraries
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Input text
text = "Natural Language Processing helps to get advance knowledge in developing AI models."

# Tokenize text into words
words = word_tokenize(text)

# Load English stopwords
stop_words = set(stopwords.words('english'))
# Remove stopwords
filtered_words = [word for word in words if word.lower() not in stop_words]

# filtered words
print("Original text:")
print(text)
print("\nText after removing stopwords:")
print(" ".join(filtered_words))
# Out:
# Original text:
# Natural Language Processing helps to get advance knowledge in developing AI models.
#
# Text after removing stopwords:
# Natural Language Processing helps get advance knowledge developing AI models .

# %%
# Example sentences
examples = [
    "The students from CS(DSA) are so vibrant.",
    "The weather today is very sunny and pleasant.",
    "We are learning Natural Language Processing using Python.",
    "Naresh is not only intelligent but also hardworking.",
    "Can you help me with this task?"
]

for i, text in enumerate(examples, 1):
    # Tokenize and remove stopwords
    words = word_tokenize(text)
    filtered = [word for word in words if word.lower() not in stop_words]

    # result
    print(f"\nExample {i}:")
    print("Original:", text)
    print("Without Stopwords:", " ".join(filtered))
# Out:
# Example 1:
# Original: The students from CS(DSA) are so vibrant.
# Without Stopwords: students CS ( DSA ) vibrant .
#
# Example 2:
# Original: The weather today is very sunny and pleasant.
# Without Stopwords: weather today sunny pleasant .
#
# Example 3:
# Original: We are learning Natural Language Processing using Python.
# Without Stopwords: learning Natural Language Processing using Python .
#
# Example 4:
# Original: Naresh is not only intelligent but also hardworking.
# Without Stopwords: Naresh intelligent also hardworking .
#
# Example 5:
# Original: Can you help me with this task?
# Without Stopwords: help task ?

# %%
pip install stopwords

# %%
from nltk.tokenize import word_tokenize

# Tamil stopwords list (custom) - Copied from previous working cell
tamil_stopwords = [
    "என்று", "இது", "அவன்", "அவள்", "அவர்", "அவர்கள்", "இவர்", "நான்",
    "நீ", "நாம்", "நீங்கள்", "எங்கள்", "உங்கள்", "ஒரு", "இந்த", "அந்த",
    "என்", "உன்", "மற்றும்", "மட்டும்", "உடன்", "மேலும்", "ஆக", "இங்கே",
    "அங்கே", "எப்போது", "எவ்வாறு", "எங்கு", "என்ன", "ஏன்"
]

# Print first 20 Tamil stopwords
print("Tamil Stopwords (sample):")
print(tamil_stopwords[:20])

# Sample Tamil sentences
sentences = [
    "நான் ஒரு புத்தகம் வாசித்தேன்.",
    "அவர் இன்று பள்ளிக்குச் சென்றார்.",
    "இந்த படம் மிகவும் அழகாக உள்ளது.",
    "அவள் என்னுடன் விளையாட விரும்புகிறாள்.",
    "நீங்கள் எப்போது வீட்டிற்கு வருவீர்கள்?"
]

# Stopword removal
for i, text in enumerate(sentences, 1):
    words = word_tokenize(text)
    filtered = [word for word in words if word not in tamil_stopwords]

    print(f"\nExample {i}:")
    print("Original:          ", text)
    print("Without Stopwords: ", " ".join(filtered))
# Out:
# Tamil Stopwords (sample):
# ['என்று', 'இது', 'அவன்', 'அவள்', 'அவர்', 'அவர்கள்', 'இவர்', 'நான்', 'நீ', 'நாம்', 'நீங்கள்', 'எங்கள்', 'உங்கள்', 'ஒரு', 'இந்த', 'அந்த', 'என்', 'உன்', 'மற்றும்', 'மட்டும்']
#
# Example 1:
# Original:           நான் ஒரு புத்தகம் வாசித்தேன்.
# Without Stopwords:  புத்தகம் வாசித்தேன் .
#
# Example 2:
# Original:           அவர் இன்று பள்ளிக்குச் சென்றார்.
# Without Stopwords:  இன்று பள்ளிக்குச் சென்றார் .
#
# Example 3:
# Original:           இந்த படம் மிகவும் அழகாக உள்ளது.
# Without Stopwords:  படம் மிகவும் அழகாக உள்ளது .
#
# Example 4:
# Original:           அவள் என்னுடன் விளையாட விரும்புகிறாள்.
# Without Stopwords:  என்னுடன் விளையாட விரும்புகிறாள் .
#
# Example 5:
# Original:           நீங்கள் எப்போது வீட்டிற்கு வருவீர்கள்?
# Without Stopwords:  வீட்டிற்கு வருவீர்கள் ?

# %% [markdown]
# ### Indic NLP Library
# The `indic-nlp-library` is a robust alternative for processing Tamil and other Indian languages.

# %%
pip install indic-nlp-library

# %%
# Using the 'indic-nlp-library' sentence splitter
from indicnlp.tokenize import sentence_tokenize

text = "நான் ஒரு புத்தகம் வாசித்தேன். அவர் இன்று பள்ளிக்குச் சென்றார்."
sentences = sentence_tokenize.sentence_split(text, lang='ta')
print("Sentences:")
for i, s in enumerate(sentences):
    print(f"{i+1}. {s}")
# Out:
# Sentences:
# 1. நான் ஒரு புத்தகம் வாசித்தேன்.
# 2. அவர் இன்று பள்ளிக்குச் சென்றார்.
