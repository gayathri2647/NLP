# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Sample documents
documents = [
    "I love natural language processing",
    "Natural language processing is a fascinating field",
    "I enjoy learning about NLP and machine learning"
]

print(documents)
# Out:
# ['I love natural language processing', 'Natural language processing is a fascinating field', 'I enjoy learning about NLP and machine learning']

# %%
# Create the TF-IDF Vectorizer
vectorizer = TfidfVectorizer()
print(vectorizer)
# Out:
# TfidfVectorizer()

# %%
# Fit and transform the documents
tfidf_matrix = vectorizer.fit_transform(documents)
print("Vocabulary Dictionary:")
print(vectorizer.vocabulary_)
print(tfidf_matrix)
# Out:
# Vocabulary Dictionary:
# {'love': 8, 'natural': 10, 'language': 6, 'processing': 12, 'is': 5, 'fascinating': 3, 'field': 4, 'enjoy': 2, 'learning': 7, 'about': 0, 'nlp': 11, 'and': 1, 'machine': 9}
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 16 stored elements and shape (3, 13)>
#   Coords	Values
#   (0, 8)	0.6046521283053111
#   (0, 10)	0.4598535287588349
#   (0, 6)	0.4598535287588349
#   (0, 12)	0.4598535287588349
#   (1, 10)	0.3494981241087058
#   (1, 6)	0.3494981241087058
#   (1, 12)	0.3494981241087058
#   (1, 5)	0.45954803293870056
#   (1, 3)	0.45954803293870056
#   (1, 4)	0.45954803293870056
#   (2, 2)	0.33333333333333337
#   (2, 7)	0.6666666666666667
#   (2, 0)	0.33333333333333337
#   (2, 11)	0.33333333333333337
#   (2, 1)	0.33333333333333337
#   (2, 9)	0.33333333333333337

# %%
# Converting sparse matrix into dense matrix
dense_matrix = tfidf_matrix.toarray()
print(dense_matrix)
# Out:
# [[0.         0.         0.         0.         0.         0.
#   0.45985353 0.         0.60465213 0.         0.45985353 0.
#   0.45985353]
#  [0.         0.         0.         0.45954803 0.45954803 0.45954803
#   0.34949812 0.         0.         0.         0.34949812 0.
#   0.34949812]
#  [0.33333333 0.33333333 0.33333333 0.         0.         0.
#   0.         0.66666667 0.         0.33333333 0.         0.33333333
#   0.        ]]

# %%
# Get feature names (vocabulary)
feature_names = vectorizer.get_feature_names_out()
print("Count of features",len(feature_names))
for word in feature_names:
    print(word)
# Out:
# Count of features 13
# about
# and
# enjoy
# fascinating
# field
# is
# language
# learning
# love
# machine
# natural
# nlp
# processing

# %%
# Convert TF-IDF matrix to a dense format and display
for i, doc_vector in enumerate(tfidf_matrix.toarray()):
    print(f"\nDocument {i+1} TF-IDF Scores:")
    for word, score in zip(feature_names, doc_vector):
        if score > 0:
            print(f"{word}: {score:.4f}")
# Out:
# Document 1 TF-IDF Scores:
# language: 0.4599
# love: 0.6047
# natural: 0.4599
# processing: 0.4599
#
# Document 2 TF-IDF Scores:
# fascinating: 0.4595
# field: 0.4595
# is: 0.4595
# language: 0.3495
# natural: 0.3495
# processing: 0.3495
#
# Document 3 TF-IDF Scores:
# about: 0.3333
# and: 0.3333
# enjoy: 0.3333
# learning: 0.6667
# machine: 0.3333
# nlp: 0.3333
